# %% [markdown]
# # Fundamentals of Bioimage Analysis: I/O and Processing
#
# ## Introduction
#
# Welcome to the 1<sup>nd</sup> notebook of the Bioimage analysis in Python course! This notebook will teach you the essential skills for reading and writing bio-image data using Python.
#
# ## Learning Objectives
#
# By completing this notebook, you will be able to:
#
# 1. **Read and write** microscopy files in various formats (CZI, OME-TIFF, etc.)
# 2. **Navigate and understand** image metadata including pixel sizes and channel information
# 3. **Visualize** multidimensional microscopy data using matplotlib and stackview
#
# ## Course Structure
#
# This notebook is divided into three main chapters:
#
# **Chapter 1: Reading and Writing Files**
# - Objective: Master the fundamentals of microscopy file I/O
# - Key Skills: Using bioio for unified file access, understanding metadata, handling different file formats
# - Take-Home: Bioio provides a standardized way to access diverse microscopy formats
#
# **Chapter 2: Visualization**
# - Objective: Learn effective strategies for visualizing multidimensional data
# - Key Skills: 2D plotting with matplotlib, 3D visualization with stackview, creating publication-quality figures
# - Take-Home: Proper visualization is essential for understanding your data and debugging analysis pipelines
#
# ## Why This Matters
#
# Modern microscopy generates complex, multidimensional datasets that require computational tools to extract meaningful information. This notebook teaches you the fundamental skills to start with reading and writing files, and basic visualization.
#
# **Let's begin!**

# %%
# !which python

try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

print(f"Running on colab {IN_COLAB}")
# Out:
# /cygdrive/c/Users/u0094799/.conda/envs/biomage-training-colab/python
# Running on colab False

# %% [markdown]
# ## Preparations
# ### Library installations on Google Colab
# When using Google Colab, we have to make sure that all the libraries that we will use are available in its runtime environment.
# Unlike local Python environments that we can reuse after a session, Google Colab will reset the environment after a certain amount of time.
# Therefore, each time we start a new Google Colab session, we have to install the libraries in the runtime environment. Luckily, Google Colab already comes with many libraries pre-installed. So, we only have to install the libraries that are not pre-installed.
#
# The following code cell will install all required libraries for this notebook.

# %%
# Pre-installed libraries (will be skipped automatically)
# !pip install numpy
# !pip install matplotlib

# To install
# !pip install bioio==3.0.0 bioio-czi==2.4.0 bioio-ome-tiff==1.4.0
# !pip install stackview==0.16.0 ipycanvas==0.11
# Out:
# Requirement already satisfied: numpy in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (2.2.6)
# ^C
# Requirement already satisfied: matplotlib in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: bioio==3.0.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (3.0.0)
# Requirement already satisfied: bioio-czi==2.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (2.4.0)
# Requirement already satisfied: bioio-ome-tiff==1.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (1.4.0)
# Requirement already satisfied: bioio-base==3.0.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio==3.0.0) (3.0.0)
# Requirement already satisfied: dask>=2021.4.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask[array]>=2021.4.1->bioio==3.0.0) (2025.7.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio==3.0.0) (2.2.6)
# Requirement already satisfied: ome-types>=0.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ome-types[lxml]>=0.4.0->bioio==3.0.0) (0.6.1)
# Requirement already satisfied: semver>=3.0.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio==3.0.0) (3.0.4)
# Requirement already satisfied: aicspylibczi>=3.2.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (3.3.1)
# Requirement already satisfied: aiohttp in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (3.12.15)
# Requirement already satisfied: fsspec>=2022.8.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (2025.9.0)
# Requirement already satisfied: lxml>=4.6 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (6.0.1)
# Requirement already satisfied: pylibczirw in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (5.0.0)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (2.9.0.post0)
# Requirement already satisfied: requests in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (2.32.5)
# Requirement already satisfied: xarray>=2022.6.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-czi==2.4.0) (2025.9.0)
# Requirement already satisfied: imagecodecs>=2020.5.30 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-ome-tiff==1.4.0) (2025.8.2)
# Requirement already satisfied: pydantic>=1.10.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-ome-tiff==1.4.0) (2.11.7)
# Requirement already satisfied: PyYAML>=6.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-ome-tiff==1.4.0) (6.0.2)
# Requirement already satisfied: tifffile>=2025.5.21 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (2025.8.28)
# Requirement already satisfied: xmlschema in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from bioio-ome-tiff==1.4.0) (4.1.0)
# Requirement already satisfied: click>=8.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio==3.0.0) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio==3.0.0) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio==3.0.0) (25.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio==3.0.0) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio==3.0.0) (1.0.0)
# Requirement already satisfied: colorama in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from click>=8.1->dask>=2021.4.1->dask[array]>=2021.4.1->bioio==3.0.0) (0.4.6)
# Requirement already satisfied: distributed==2025.7.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (2025.7.0)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (1.1.1)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (7.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (6.5.2)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (2.5.0)
# Requirement already satisfied: zict>=3.0.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from jinja2>=2.10.3->distributed==2025.7.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base==3.0.0->bioio==3.0.0) (3.0.2)
# Requirement already satisfied: pydantic-extra-types in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio==3.0.0) (2.10.5)
# Requirement already satisfied: xsdata<24.4,>=23.6 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio==3.0.0) (24.3.1)
# Requirement already satisfied: typing-extensions in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from xsdata<24.4,>=23.6->ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio==3.0.0) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pydantic>=1.10.0->bioio-ome-tiff==1.4.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pydantic>=1.10.0->bioio-ome-tiff==1.4.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pydantic>=1.10.0->bioio-ome-tiff==1.4.0) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from python-dateutil>=2.9.0.post0->bioio-czi==2.4.0) (1.17.0)
# Requirement already satisfied: zarr>=3 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (3.1.2)
# Requirement already satisfied: kerchunk in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (0.2.9)
# Requirement already satisfied: pandas>=2.2 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from xarray>=2022.6.0->bioio-czi==2.4.0) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-czi==2.4.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-czi==2.4.0) (2025.2)
# Requirement already satisfied: donfig>=0.8 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from zarr>=3->tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from numcodecs[crc32c]>=0.14->zarr>=3->tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (0.16.2)
# Requirement already satisfied: crc32c>=2.7 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from numcodecs[crc32c]>=0.14->zarr>=3->tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (2.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from aiohttp->bioio-czi==2.4.0) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->bioio-czi==2.4.0) (3.10)
# Requirement already satisfied: ujson in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from kerchunk->tifffile[zarr]>=2025.5.21; python_version >= "3.11"->bioio-ome-tiff==1.4.0) (5.11.0)
# Requirement already satisfied: cmake in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pylibczirw->bioio-czi==2.4.0) (4.1.0)
# Requirement already satisfied: xmltodict in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pylibczirw->bioio-czi==2.4.0) (0.15.0)
# Requirement already satisfied: validators in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from pylibczirw->bioio-czi==2.4.0) (0.35.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from requests->bioio-czi==2.4.0) (3.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from requests->bioio-czi==2.4.0) (2025.8.3)
# Requirement already satisfied: elementpath<6.0.0,>=5.0.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from xmlschema->bioio-ome-tiff==1.4.0) (5.0.4)
# Requirement already satisfied: stackview==0.16.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (0.16.0)
# Requirement already satisfied: ipycanvas==0.11 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy!=1.19.4 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (2.2.6)
# Requirement already satisfied: ipywidgets in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (8.1.7)
# Requirement already satisfied: scikit-image in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (0.25.2)
# Requirement already satisfied: ipyevents in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (2.0.2)
# Requirement already satisfied: toolz in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (1.0.0)
# Requirement already satisfied: matplotlib in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (3.10.5)
# Requirement already satisfied: ipykernel in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (6.30.1)
# Requirement already satisfied: imageio in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (2.37.0)
# Requirement already satisfied: ipympl in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (0.9.7)
# Requirement already satisfied: wordcloud in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stackview==0.16.0) (1.9.4)
# Requirement already satisfied: pillow>=6.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipycanvas==0.11) (11.3.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipywidgets->stackview==0.16.0) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipywidgets->stackview==0.16.0) (9.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipywidgets->stackview==0.16.0) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipywidgets->stackview==0.16.0) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipywidgets->stackview==0.16.0) (3.0.15)
# Requirement already satisfied: colorama in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.4.6)
# Requirement already satisfied: decorator in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.8.5)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (1.8.16)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (5.8.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from ipykernel->stackview==0.16.0) (6.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from jupyter-client>=8.0.0->ipykernel->stackview==0.16.0) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->stackview==0.16.0) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->stackview==0.16.0) (311)
# Requirement already satisfied: six>=1.5 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->stackview==0.16.0) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib->stackview==0.16.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib->stackview==0.16.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib->stackview==0.16.0) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib->stackview==0.16.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from matplotlib->stackview==0.16.0) (3.2.3)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from scikit-image->stackview==0.16.0) (1.16.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from scikit-image->stackview==0.16.0) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from scikit-image->stackview==0.16.0) (2025.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from scikit-image->stackview==0.16.0) (0.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->stackview==0.16.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->stackview==0.16.0) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\u0094799\.conda\envs\biomage-training-colab\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->stackview==0.16.0) (0.2.3)

# %% [markdown]
# ### Download the image dataset
# We will work with a demo microscopy dataset in which HeLa cells have been stained using DAPI, and tubulin and mitochondria antibodies. Hereto, we will download the image dataset into our Google Drive.

# %%
import gdown

# a file
url = "https://drive.google.com/uc?id=1tR0yOZ7vOwMz43RacDNw77oGi50pbBrd"
if IN_COLAB :
    image_path = "/content/hela_prolongdiamond_dapi_tubulin-af488_mitochondria-af568_40x.czi"
    gdown.download(url, image_path)

# %% [markdown]
# # Chapter 1: Reading and Writing Files
# In this chapter, we will learn how to read and write microscopy files in various formats.
# Hereto, we will use the convenient `bioio` library that will handle a lot of the heavy lifting for us.
# It provides a unified interface for reading and writing microscopy files in various formats.
#
# ## 1.1. Reading Files
#
# **Importing the `bioio` library**
#
# We will start by reading files using the `bioio` library. The following code cell will import all the elements from `bioio` that we will use to read files in this notebook.

# %%
# Bioio imports
from bioio import BioImage
from bioio_ome_tiff.writers import OmeTiffWriter
import bioio_base as biob

# %% [markdown]
# **Reading a file**
#
# We can now define a variable containing the path to the image file that we want to read. In this example, we have a .czi file, which is a file format used by Zeiss microscopes.
#
# ```python
# image_path = "/content/sample_data/hela_prolongdiamond_dapi_tubulin-af488_mitochondria-af568_40x.czi"
# ```
#
# We can then use the `BioImage` class to read the file.
#
# ```python
# img = BioImage(image_path)
# ```
# A microscopy image file can contain multiple acquisitions, called scenes in `bioio`. We can specify which scene we want to read, but by default, the first scene will be read.
#
# We can then print the id of the current scene using the `current_scene` attribute.
#
# ```python
# print(img.current_scene)
# ```
#
# We can also get a list of all the scenes in the file using the `scenes` attribute.
#
# ```python
# print(img.scenes)
# ```

# %%
# Define the path to the image file
if IN_COLAB :
    image_path = "/content/hela_prolongdiamond_dapi_tubulin-af488_mitochondria-af568_40x.czi"
else:
    image_path = "../data/hela_prolongdiamond_dapi_tubulin-af488_mitochondria-af568_40x.czi"

# Define a BioImage object
img = BioImage(image_path)  # selects the first scene found

# Get the id of the current operating scene
print(f'Current scene: {img.current_scene}')

# Get a list valid scene ids
print(f'Scenes: {img.scenes}')
# Out:
# Current scene: 0
# Scenes: ('0', '1', '2', '3')

# %% [markdown]
# **Changing the scene**
#
# To read another acquisition, a.k.a. scene, we can use the `set_scene` method.
#
# This can be done by specifying the scene id, a string that is the name of the scene.
# ```python
# img.set_scene("1")
# ```
#
# We can also use the `set_scene` method with the scene index.
#
# ```python
# img.set_scene(1)
# ```

# %%
# Change scene using name
img.set_scene("1")
# Or by scene index
img.set_scene(1)

print(f'Current scene: {img.current_scene}')
# Out:
# Current scene: 1

# %% [markdown]
# **Accessing image metadata**
#
# The `BioImage` class provides a lot of metadata about the image. We can access it as attributes of our `img` object.

# %%
# Access all the metadata
print(img.metadata)  # returns the metadata object for this file format (XML, JSON, etc.)
# Out:
# <Element 'ImageDocument' at 0x000001BE17EA7560>

# %%
print(img.ome_metadata) # returns the OME-XML metadata as a string
# Out:
# experimenters=[{'id': 'Experimenter:u0119446', 'user_name': 'u0119446'}] instruments=[<1 field_type>] images=[<4 field_type>] structured_annotations={'xml_annotations': [{'description': 'AIMApplication14.0.29.201', 'id': 'urn:lsid:allencell.org:Annotation:AcquisitionSoftware', 'value': {}, 'kind': 'xmlannotation'}]}

# %%
# Access specific metadata
print(f'Dimensions object: {img.dims}')  # returns a Dimensions object
print(f'Dimension order: {img.dims.order}')  # returns string "TCZYX"
print(f'Size of X dimension: {img.dims.X}')  # returns size of X dimension
print(f'Shape: {img.shape}')  # returns tuple of dimension sizes in TCZYX order

print(f'Channel names: {img.channel_names}')  # returns a list of string channel names found in the metadata
print(f'Z dimension pixel size: {img.physical_pixel_sizes.Z}')  # returns the Z dimension pixel size as found in the metadata
print(f'Y dimension pixel size: {img.physical_pixel_sizes.Y}')  # returns the Y dimension pixel size as found in the metadata
print(f'X dimension pixel size: {img.physical_pixel_sizes.X}')  # returns the X dimension pixel size as found in the metadata
# Out:
# Dimensions object: <Dimensions [T: 1, C: 3, Z: 14, Y: 512, X: 512]>
# Dimension order: TCZYX
# Size of X dimension: 512
# Shape: (1, 3, 14, 512, 512)
# Channel names: [np.str_('Ch2-T1'), np.str_('ChS1-T2'), np.str_('Ch1-T3')]
# Z dimension pixel size: 1.0
# Y dimension pixel size: 0.4151329104819196
# X dimension pixel size: 0.4151329104819196

# %% [markdown]
# BioIO utilizes File-System Specification (fsspec) to read directly from remote resources like object storage services (S3, GCS, etc.) and simple http URL (see [documentation](https://bioio-devs.github.io/bioio/OVERVIEW.html#cloud-io-support)).
#
# Here is an example to read from an HTTP URL

# %%
url = "https://github.com/vib-bic-training/vib_bioimage_analysis_in_python/raw/refs/heads/main/data/02_hela_prolongdiamond_dapi_tubulin-af488_mitochondria-af568.ome.czi"
img = BioImage(url)
print(f'Dimensions object: {img.dims}')  # returns a Dimensions object
print(f'Dimension order: {img.dims.order}')  # returns string "TCZYX"
print(f'Size of X dimension: {img.dims.X}')  # returns size of X dimension
print(f'Shape: {img.shape}')  # returns tuple of dimension sizes in TCZYX order
print(f'Channel names: {img.channel_names}')  # returns a list of string channel names found in the metadata
print(f'Z dimension pixel size: {img.physical_pixel_sizes.Z}')  # returns the Z dimension pixel size as found in the metadata
print(f'Y dimension pixel size: {img.physical_pixel_sizes.Y}')  # returns the Y dimension pixel size as found in the metadata
print(f'X dimension pixel size: {img.physical_pixel_sizes.X}')  # returns the X dimension pixel size as found in the metadata
# Out:
# Dimensions object: <Dimensions [T: 1, C: 3, Z: 14, Y: 512, X: 512]>
# Dimension order: TCZYX
# Size of X dimension: 512
# Shape: (1, 3, 14, 512, 512)
# Channel names: [np.str_('Ch2-T1'), np.str_('ChS1-T2'), np.str_('Ch1-T3')]
# Z dimension pixel size: 1.0
# Y dimension pixel size: 0.4151329104819196
# X dimension pixel size: 0.4151329104819196

# %% [markdown]
# In Bio-image analysis, we frequently deal with 5D arrays. Here is a table summarizing them wiht the TCZYX order:
# |   Index |   Axis    |  Logic |
# |   ----- |   ----    |  ----- |
# |   0     | T (Time)  | Sequence of events. |
# | 1       |	C (Channel)| sensors/fluorophores. |
# | 2	| Z | (Plane) | Physical depth in the sample. |
# | 3	| Y | (Height)| Row index.|
# | 4	| X | (Width) |	Column index.|

# %% [markdown]
# ### Bioio Conversion
#
# https://github.com/bioio-devs/bioio-
#
# A library from the same team as bioio to convert bioio supported file format to ome.zarr

# %% [markdown]
# ## 1.2. Writing Files
#
# We can also write files using the `bioio` library.
#
# Hereto, we first define the output path, i.e. the path where we want to write the file to.
# ```python
# output_path="/content/images/output.ome.tiff"
# ```
#
# We can then use the `write_file` method to write the file.
#
# ```python
# img.write_file("output.ome.tiff")
# ```
#
# In this case, we are writing the image into an OME-TIFF file that will use the same metadata as the original file.

# %%
# Define the output path
if IN_COLAB :
    output_path="/content/output.ome.tiff"
else:
     output_path="../output.ome.tiff"

# Write the file
img.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Define the output path
# ----> 2 if IN_COLAB :
#       3     output_path="/content/output.ome.tiff"
#       4 else:
#
# NameError: name 'IN_COLAB' is not defined

# %% [markdown]
# **Open the image as a numpy array**

# %%
# Get the raw data as a numpy array
data = img.get_image_data("CZYX", T=0)  # returns 4D CZYX numpy array
print(f'Data type: {type(data)}')
print(f'Numpy array shape: {data.shape}')

# %% [markdown]
# We can now write the data to a new file. Hereto, we will import the `OmeTiffWriter` class from the `bioio` library that allows us to create a new OME-TIFF file from scratch.
#
# We will also define the metadata that we want to stored in the new file. To do this in a standardized way, we will also import `bioio_base` that contains the base classes for the metadata. For convenience, we call it `biob`.

# %%
# Import the OmeTiffWriter class
from bioio.writers import OmeTiffWriter
import bioio_base as biob

# Get the raw data as a numpy array
data = img.get_image_data("CZYX", T=0)  # returns 4D CZYX numpy array
print(f'Numpy array shape: {data.shape}')

# Define the output path
if IN_COLAB :
    output_path="/content/output.ome.tiff"
else:
    output_path="../data/output.ome.tiff"

# Define the metadata
write_dim_order = "CZYX"  # required, the dimension order to write the data in
channel_names = ['Mitochondria', 'Tubulin', 'DAPI']
channel_colors = [(255,0,255), (0,255,0), (0,255,255)]  # Magenta/Green/Cyam, colors in RGB format
pixel_size = biob.types.PhysicalPixelSizes(
    img.physical_pixel_sizes.Z,
    img.physical_pixel_sizes.Y,
    img.physical_pixel_sizes.X
    )  # optional, Z, Y, X in microns

# Write the file
OmeTiffWriter.save(
        data,
        output_path,
        write_dim_order,
        channel_names=channel_names,
        channel_colors=channel_colors,
        physical_pixel_sizes=pixel_size,
    )

# %% [markdown]
# **Reading the stored file**
#
# We can now read the file we just wrote using the `BioImage` class.

# %%
img = BioImage(output_path)
print(f'Dimensions object: {img.dims}')  # returns a Dimensions object
print(f'Dimension order: {img.dims.order}')  # returns string "TCZYX"
print(f'Size of X dimension: {img.dims.X}')  # returns size of X dimension
print(f'Shape: {img.shape}')  # returns tuple of dimension sizes in TCZYX order

print(f'Channel names: {img.channel_names}')  # returns a list of string channel names found in the metadata
print(f'Z dimension pixel size: {img.physical_pixel_sizes.Z}')  # returns the Z dimension pixel size as found in the metadata
print(f'Y dimension pixel size: {img.physical_pixel_sizes.Y}')  # returns the Y dimension pixel size as found in the metadata
print(f'X dimension pixel size: {img.physical_pixel_sizes.X}')  # returns the X dimension pixel size as found in the metadata
# Out:
# Dimensions object: <Dimensions [T: 1, C: 3, Z: 14, Y: 512, X: 512]>
# Dimension order: TCZYX
# Size of X dimension: 512
# Shape: (1, 3, 14, 512, 512)
# Channel names: [np.str_('Mitochondria'), np.str_('Tubulin'), np.str_('DAPI')]
# Z dimension pixel size: 1.0
# Y dimension pixel size: 0.4151329104819196
# X dimension pixel size: 0.4151329104819196

# %% [markdown]
# # Chapter2: Visualisation
# Now that we know how to read and write files, we can start visualising the data. In this chapter, we will explore various ways to visualize the data, from simple 2D images to 3D volumes.
#
# For this, we will use a couple of new libraries:
# - matplotlib: for simple 2D and 3D image visualisation and data plotting
# - stackview: for more advanced visualisation of images, volumes and time-series
#
# ## 2.1. Matplotlib for 2D image visualisation and data plotting
#
# **2D image visualisation**
#
# First, let's visualize the images in 2D using matplotlib.

# %%
# Define the image path
image_path = "/content/hela_prolongdiamond_dapi_tubulin-af488_mitochondria-af568_40x.czi"

# Define a BioImage object
img = BioImage(image_path)
print(f'Image shape: {img.shape}')
print(f'Image dimensions: {img.dims.order}')
print(f'Image physical pixel sizes: {img.physical_pixel_sizes}')
print(f'Image channel names: {img.channel_names}')

# Create variables from metadata
channel_names = img.channel_names
image_scale = [img.physical_pixel_sizes.Z, img.physical_pixel_sizes.Y, img.physical_pixel_sizes.X]

# Create colormaps for each channel, e.g., from black to magenta
from matplotlib.colors import LinearSegmentedColormap
cmap_magenta = LinearSegmentedColormap.from_list("magenta", ['black', 'magenta'])
cmap_green =  LinearSegmentedColormap.from_list("green", ['black', 'green'])
cmap_cyan = LinearSegmentedColormap.from_list("cyan", ['black', 'cyan'])
cmap_list = [cmap_magenta, cmap_green, cmap_cyan]

# First, let use visualize the images in 2D using matplotlib
# The images are multi-dimensional. We will plot each channel in a separate subplot.
# For each channel we will use a maximum intensity projection (MIP).
import numpy as np
import matplotlib.pyplot as plt

# Make sure matplotlib is displayed inline in the notebook
# %matplotlib inline

# Get the raw data as a numpy array
data = img.get_image_data("CZYX", T=0) # returns 4D CZYX numpy array
data_mip = np.max(data, axis=1) # returns 3D CYX numpy array (C=3, Y=1024, X=1024) containing MIP images.

# Create a figure with 3 subplots, 1 for each channel, arranged horizontally
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, channel in enumerate(channel_names):
    data_mip_channel = data_mip[i,:,:] # Get the MIP image for the i-th channel
    cmap = plt.get_cmap(cmap_list[i]) # Get the colormap for the i-th channel
    axes[i].imshow(data_mip_channel, cmap=cmap)
    axes[i].set_title(channel) # Set the title of the subplot to the channel name
    axes[i].axis('off') # Remove the axis ticks
plt.show()
# Out:
# Image shape: (1, 3, 14, 512, 512)
# Image dimensions: TCZYX
# Image physical pixel sizes: PhysicalPixelSizes(Z=1.0, Y=0.4151329104819196, X=0.4151329104819196)
# Image channel names: [np.str_('Ch2-T1'), np.str_('ChS1-T2'), np.str_('Ch1-T3')]

# %% [markdown]
# **Bonus:** Above, we used a for-loop. A for-loop iterates over the elements of the variable you give it. Think of it as "for each element in the list, do the following:". For example:
#
# ```python
# for i in [a,b,c]:
#     print(i)
# ```
#
# In the example above, we also used `enumerate`. This is an iterable that returns both the indexes and the elements it is iterating over. For example:
#
# ```python
# for i, element in enumerate([a,b,c]):
#     print(i, element)
# ```

# %% [markdown]
# **Data plotting**
#
# Besides visualizing 2D images, we can also use matplotlib to plot data.
#
# For example, we can plot the intensity distribution of the different channels.

# %%
# Create a plot with the histograms of the different channels
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, channel in enumerate(channel_names):
    data_mip_channel = data_mip[i,:,:] # Get the MIP image for the i-th channel
    cmap = cmap_list[i] # Get the colormap for the i-th channel
    # Plot the histogram of the channel
    axes[i].hist(
        data_mip_channel.flatten(), # Flatten the image to a 1D array
        bins=100,
        color=cmap.name,
        alpha=0.5
        )
    axes[i].set_title(channel) # Set the title of the subplot to the channel name
    axes[i].set_xlabel('Intensity') # Set the x-axis label to 'Intensity'
    axes[i].set_ylabel('Frequency') # Set the y-axis label to 'Frequency'
plt.show()

# %% [markdown]
# ## 2.2. Visualzing volumes with Stackview
#
# Stackview is a convinient tool for visualizing  multi-dimensional data. Here, we will use it to visuale the 3D volume. To use it, we will first have to activate widgets in Google Colab.

# %%
# Activate widgets in google colab
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Now, let's use `stackview`'s `insight` function to display statistical information about the image.

# %%
import stackview
stackview.insight(img.get_image_data("ZYX", C=1, T=0))
# Out:
# <table>
# <tr>
# <td>
# <img src="data:image/png;base64,..."></img>
# </td>
# <td style="text-align: center; vertical-align: top;">
#
# <table>
# <tr><td>shape</td><td>(14,&nbsp;512,&nbsp;512)</td></tr>
# <tr><td>dtype</td><td>uint16</td></tr>
# <tr><td>size</td><td>7.0 MB</td></tr>
# <tr><td>min</td><td>0</td></tr><tr><td>max</td><td>2345</td></tr>
# </table>
# <img src="data:image/png;base64,..."></img>
# </td>
# </tr>
# </table>

# %% [markdown]
# Visualze a different channel:

# %%
images = {
    "mitochondria": img.get_image_data("ZYX", C=0, T=0),
    "tubulin": img.get_image_data("ZYX", C=1, T=0),
    "nuclei": img.get_image_data("ZYX", C=2, T=0)
    }

stackview.switch(
    images,
    colormap=["pure_magenta", "pure_green", "pure_blue"],
    toggleable=True
)

# %% [markdown]
# Orthogonal views:

# %%
stackview.orthogonal(img.get_image_data("ZYX", C=1, T=0))

# %% [markdown]
# More options with stackview:
# * side_by_side
# * switch
# * curtain
#
# These will be used later to show the result of a cell segmentation
#
# ## Stackview References:
# 🔗 https://github.com/haesleinhuepf/stackview
